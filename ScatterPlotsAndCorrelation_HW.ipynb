# %% [markdown]
# <a href="https://colab.research.google.com/github/KayleeM05/KayleeM05/blob/CMU-Math4AI-Work/ScatterPlotsAndCorrelation_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://www.andrew.cmu.edu/user/dvaroday/Math4AI/data/fertility-and-life-expectancy-2024.txt'
df = pd.read_table(url, sep='\t', engine='python')

display(df)
# Out:
#                  Location  Fertility  Life_expectancy
# 0                   Aruba      1.657           73.075
# 1             Afghanistan      4.843           59.193
# 2                  Angola      6.080           50.802
# 3                 Albania      1.784           75.369
# 4    United Arab Emirates      1.784           76.295
# ..                    ...        ...              ...
# 195           Yemen, Rep.      4.160           62.486
# 196          South Africa      2.363           55.167
# 197      Congo, Dem. Rep.      6.006           57.247
# 198                Zambia      5.353           58.229
# 199              Zimbabwe      3.923           56.171
#
# [200 rows x 3 columns]

# %%
## Q1.1

corr_coef_matrix = df.corr(numeric_only=True)
display(corr_coef_matrix)
# Out:
#                  Fertility  Life_expectancy
# Fertility         1.000000        -0.799376
# Life_expectancy  -0.799376         1.000000

# %%
## Q1.2

plt.scatter(df.Fertility, df.Life_expectancy)
for i, txt in enumerate(df.Location):
    plt.annotate(txt, (df.Fertility[i],df.Life_expectancy[i]))
plt.subplots_adjust(bottom=0, top=1.5, left=0, right=1.5)
plt.xlabel('Fertility')
plt.ylabel('Life expectancy')
plt.title('Fertility vs. Life expect')
# Out:
# Text(0.5, 1.0, 'Fertility vs. Life expect')

# %%
## Q1.3

df_remove_one = df[df.Location!='Niger']
corr_coef_matrix = df_remove_one.corr(numeric_only=True)
display(corr_coef_matrix)
# Out:
#                  Fertility  Life_expectancy
# Fertility         1.000000        -0.808068
# Life_expectancy  -0.808068         1.000000
